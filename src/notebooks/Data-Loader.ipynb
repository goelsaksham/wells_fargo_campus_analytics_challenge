# %% [markdown]
# # Data Loader
#
# This notebook is responsible to load the data from the excel file from both the sheets and just clean it up a little bit and save the data into csv files which is easier for loading in further analysis

# %% [markdown]
# ### Section 1: Importing the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
import os
import glob
import re

# %% [markdown]
# ### Section 2: Loading the Data from the Excel File

# %%
indv_data_df= pd.read_excel(r'../../data/input_data/Data+campus_challenge_FINAL.xlsx', sheet_name = 'Individuals')

# %%
indv_data_df.head()
# Out:
#    Indnum  Group                  Activity  Units  Consumption  \
# 0       1      1  Household heating => 70F  hours          2.0
# 1       1      1   Household heating < 70F  hours         10.0
# 2       1      1          Use of heat pump  hours          NaN
# 3       1      1    Use of air conditioner  hours         20.0
# 4       1      2            shower - short  count          5.0
#
#    Quality_of_Life_Importance__1_10  solar_powered__water_heater  \
# 0                              88.0                          NaN
# 1                              85.0                          1.0
# 2                              50.0                          NaN
# 3                              45.0                          NaN
# 4                              98.0                          NaN
#
#    gas_water_heater  electric_water_heater___peak_hou  \
# 0               NaN                               NaN
# 1               1.0                               NaN
# 2               NaN                               NaN
# 3               NaN                               NaN
# 4               NaN                               NaN
#
#    electric_water_heater___off_peak  gas  natural_gas  hybrid  \
# 0                               NaN  NaN          1.0     NaN
# 1                               NaN  NaN          1.0     NaN
# 2                               NaN  NaN          NaN     NaN
# 3                               NaN  NaN          NaN     NaN
# 4                               NaN  NaN          NaN     NaN
#
#    electric___peak_hours  electric___off_peak_hours  jetfuel
# 0                    NaN                        NaN      NaN
# 1                    NaN                        NaN      NaN
# 2                    NaN                        NaN      NaN
# 3                    NaN                        NaN      NaN
# 4                    NaN                        NaN      NaN

# %%
indv_data_df.shape
# Out:
# (27054, 16)

# %%
carbon_footprint_data_df = pd.read_excel(r'../../data/input_data/Data+campus_challenge_FINAL.xlsx', sheet_name = r'Carbon Footprint', skiprows=1, index_col = 0, na_values=0)

# %%
carbon_footprint_data_df
# Out:
#                                           Activity        Per  \
# 1                         Household heating => 70F      hour
# 2                          Household heating < 70F      hour
# 3                                 Use of heat pump      hour
# 4                          Use of air conditioner       hour
# 5                                   shower - short   activity
# 6                          shower - long (> 3 min)   activity
# 7                                             bath   activity
# 8                                          wash-up   activity
# 9                                use of dishwasher   activity
# 10                           use of clothes washer   activity
# 11                           use of clothes dryer    activity
# 12                            use of cooking range   activity
# 13                                    use of  oven   activity
# 14      use of self-clean feature of electric oven   activity
# 15            Small kitchen applicance in the home   activity
# 16                                 TV/computer use      hour
# 17                        air travel - large plane  100 miles
# 18          air travel - small  plane (<50 seats)   100 miles
# 19                            car trips- self only     mile
# 20                     car trips - driver and self     mile
# 21  car trips - 2+ people with multiple end points     mile
# 22        trips using public ground transportation     mile
# 23                        bags of garbage disposed    per bag
# 24       bags of recycling deposited (negative CF)    per bag
# 25         bags of compost deposited (negative CF)    per bag
# 26            hazardous or electric items disposed   per item
# 27                            large items disposed   per item
#
#     solar powered  water heater  gas water heater  \
# 1                           NaN               NaN
# 2                           NaN               NaN
# 3                           NaN               NaN
# 4                           NaN               NaN
# 5                      0.000012          0.000102
# 6                      0.000017          0.000149
# 7                      0.000088          0.000254
# 8                      0.000004          0.000042
# 9                      0.000025          0.000165
# 10                     0.000033          0.000199
# 11                          NaN               NaN
# 12                          NaN               NaN
# 13                          NaN               NaN
# 14                          NaN               NaN
# 15                          NaN               NaN
# 16                          NaN               NaN
# 17                          NaN               NaN
# 18                          NaN               NaN
# 19                          NaN               NaN
# 20                          NaN               NaN
# 21                          NaN               NaN
# 22                          NaN               NaN
# 23                          NaN               NaN
# 24                          NaN               NaN
# 25                          NaN               NaN
# 26                          NaN               NaN
# 27                          NaN               NaN
#
#     electric water heater - peak hours  \
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                             0.000232
# 6                             0.000354
# 7                             0.000412
# 8                             0.000067
# 9                             0.000398
# 10                            0.000433
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
#
#     electric water heater - off peak hours       gas  natural gas  Jet Fuel  \
# 1                                      NaN       NaN     0.000436       NaN
# 2                                      NaN       NaN     0.000872       NaN
# 3                                      NaN       NaN     0.001074       NaN
# 4                                      NaN       NaN     0.000598       NaN
# 5                                 0.000199       NaN          NaN       NaN
# 6                                 0.000312       NaN          NaN       NaN
# 7                                 0.000368       NaN          NaN       NaN
# 8                                 0.000055       NaN          NaN       NaN
# 9                                 0.000311       NaN          NaN       NaN
# 10                                0.000382       NaN     0.000154       NaN
# 11                                     NaN       NaN     0.000187       NaN
# 12                                     NaN       NaN     0.000201       NaN
# 13                                     NaN       NaN     0.000255       NaN
# 14                                     NaN       NaN          NaN       NaN
# 15                                     NaN       NaN          NaN       NaN
# 16                                     NaN       NaN          NaN       NaN
# 17                                     NaN       NaN          NaN    0.0179
# 18                                     NaN       NaN          NaN    0.0408
# 19                                     NaN  0.000551          NaN       NaN
# 20                                     NaN  0.000554          NaN       NaN
# 21                                     NaN  0.000354          NaN       NaN
# 22                                     NaN  0.000276          NaN       NaN
# 23                                     NaN       NaN          NaN       NaN
# 24                                     NaN       NaN          NaN       NaN
# 25                                     NaN       NaN          NaN       NaN
# 26                                     NaN       NaN          NaN       NaN
# 27                                     NaN       NaN          NaN       NaN
#
#     waste management    hybrid  electric - peak hours  \
# 1                NaN       NaN               0.000650
# 2                NaN       NaN               0.000923
# 3                NaN       NaN               0.001229
# 4                NaN       NaN               0.007980
# 5                NaN       NaN                    NaN
# 6                NaN       NaN                    NaN
# 7                NaN       NaN                    NaN
# 8                NaN       NaN                    NaN
# 9                NaN       NaN               0.000084
# 10               NaN       NaN               0.000102
# 11               NaN       NaN               0.000132
# 12               NaN       NaN               0.000142
# 13               NaN       NaN               0.000162
# 14               NaN       NaN               0.000199
# 15               NaN       NaN               0.000054
# 16               NaN       NaN               0.000002
# 17               NaN       NaN                    NaN
# 18               NaN       NaN                    NaN
# 19               NaN  0.000332               0.000192
# 20               NaN  0.000337               0.000199
# 21               NaN  0.000123               0.000032
# 22               NaN       NaN                    NaN
# 23            0.0419       NaN                    NaN
# 24           -0.0419       NaN                    NaN
# 25           -0.0419       NaN                    NaN
# 26            0.0211       NaN                    NaN
# 27            0.0211       NaN                    NaN
#
#     electric - off peak hours  Unnamed: 14  \
# 1                    0.000542          NaN
# 2                    0.000901          NaN
# 3                    0.001188          NaN
# 4                    0.000721          NaN
# 5                         NaN          NaN
# 6                         NaN          NaN
# 7                         NaN          NaN
# 8                         NaN          NaN
# 9                    0.000078          NaN
# 10                   0.000093          NaN
# 11                   0.000122          NaN
# 12                   0.000135          NaN
# 13                   0.000150          NaN
# 14                   0.000178          NaN
# 15                   0.000041          NaN
# 16                   0.000002          NaN
# 17                        NaN          NaN
# 18                        NaN          NaN
# 19                   0.000233          NaN
# 20                   0.000245          NaN
# 21                   0.000055          NaN
# 22                        NaN          NaN
# 23                        NaN          NaN
# 24                        NaN          NaN
# 25                        NaN          NaN
# 26                        NaN          NaN
# 27                        NaN          NaN
#
#                                                 Notes
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  For electric cars, peak vs. offpeak refers to ...
# 20  For electric cars, peak vs. offpeak refers to ...
# 21  For electric cars, peak vs. offpeak refers to ...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN

# %%
carbon_footprint_data_df.shape
# Out:
# (27, 15)

# %%
carbon_footprint_data_df_select_data = carbon_footprint_data_df.drop(['Unnamed: 14', 'Notes'], axis = 1)

# %%
carbon_footprint_data_df_select_data.shape
# Out:
# (27, 13)

# %%
carbon_footprint_data_df_select_data_table = pd.melt(carbon_footprint_data_df_select_data, id_vars=['Activity', 'Per'], value_vars=list(carbon_footprint_data_df.columns.values)[2:])
# Out:
# C:\Users\Saksham Goel\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py:731: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   frame = frame.loc[:, id_vars + value_vars]
# C:\Users\Saksham Goel\Anaconda3\lib\site-packages\pandas\core\indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
carbon_footprint_data_df_select_data_table.shape
# Out:
# (351, 4)

# %%
carbon_footprint_data_df_select_data_table_without_na = carbon_footprint_data_df_select_data_table.dropna(axis = 0)

# %%
carbon_footprint_data_df_select_data_table_without_na.shape
# Out:
# (76, 4)

# %%
carbon_footprint_data_df_select_data_table.to_csv(r'../../data/input_data/Carboon_Footprint_Table.csv')
carbon_footprint_data_df_select_data_table_without_na.to_csv(r'../../data/output_data/Carboon_Footprint_Table.csv')

# %%
indv_data_df.to_csv(r'../../data/input_data/Individual_Data.csv')
indv_data_df.to_csv(r'../../data/output_data/Individual_Data.csv')
